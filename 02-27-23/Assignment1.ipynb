# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.model_selection import cross_val_score

# %%
data = pd.read_csv("/content/drive/MyDrive/#2-M.Sc Computer Science [SXC]/1st Year/Books and notes/Sem 4/Machine Learning/SM+SS/27-02-23/diabetes.csv")
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
sns.heatmap(data.corr())
plt.title('Correlation On iris Classes')
# Out:
# Text(0.5, 1.0, 'Correlation On iris Classes')

# %%
data.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x=data.iloc[:,:-1]
y=data.iloc[:,8]

# %%
x_train,x_test, y_train, y_test=train_test_split(x,y,test_size=0.1, random_state=43)

# %%
model = SVC()
model.fit(x_train, y_train)
# Out:
# SVC()

# %%
pred = model.predict(x_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# %%
print(classification_report(y_test, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.93      0.88        54
#            1       0.76      0.57      0.65        23
#
#     accuracy                           0.82        77
#    macro avg       0.80      0.75      0.76        77
# weighted avg       0.81      0.82      0.81        77

# %%
"{0:.2f}%".format(accuracy_score(y_test, pred) * 100)
# Out:
# '81.82%'

# %%
cm = confusion_matrix(y_test, pred)
cm
# Out:
# array([[50,  4],
#        [10, 13]])

# %%
classes = data['Outcome'].unique()

df_cm = pd.DataFrame(cm, classes, classes)
sns.heatmap(df_cm, annot=True, cmap="PuBu")
plt.xlabel("Actual Values")
plt.ylabel("Predicted Values")
plt.show()

# %%
from joblib import dump

# %%
dump(model, '/content/drive/MyDrive/#2-M.Sc Computer Science [SXC]/1st Year/Books and notes/Sem 4/Machine Learning/SM+SS/27-02-23/svm.model')
# Out:
# ['/content/drive/MyDrive/#2-M.Sc Computer Science [SXC]/1st Year/Books and notes/Sem 4/Machine Learning/SM+SS/27-02-23/svm.model']
